# %% [markdown]
# # Building makemore Part 5: Building a WaveNet
#
# 📺 **Video:** [Building makemore Part 5: Building a WaveNet](https://youtu.be/t3YJ5hKiMQ0)
#
# # Building makemore Part 5: Building a WaveNet
#
# > Notlar buraya gelecek.
